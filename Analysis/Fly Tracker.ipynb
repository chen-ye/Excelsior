# %%
#! /anaconda/bin/python

# Access the original .xml files from Chen Ye (cy27)
    # find /users/aspierer/FlyLapse/youngII_images/ -iname '*.xml' -type f -exec cp '{}' /users/aspierer/FlyLapse_xmls/young_flies \;
    ## Change the paths when needed

# Example file name: Tracked_Batch_Preprocessed_VFlylapse_Rack12_Rep3_20-06-12.ti
# Example xml header: <Tracks nTracks="142" spaceUnits="cm" frameInterval="0.1333329975605011" timeUnits="sec" generationDateTime="Thu, 31 Jul 2014 01:43:03" from="TrackMate v2.3.1-SNAPSHOT">

    
# Things to do:
	# Integrate python and R scripts into this notebook
	# Incorporate data from title (date, replicate #, etc.) and the new data structure format
	# Incorporate categorical info for tube number 
    # Convert measurements from pixels to millimeters


import re
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import rpy2

# %matplotlib inline

os.chdir("/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/")

# %%
## YOUNG Flies XML to CSV

## Should write a function to do all this so it is more user friendly

folder = "/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/young_flies_xmls"
os.chdir(folder)

all_xmls = {}

def get_xml(folder):
    return {folder: [File for File in os.listdir(folder) if File.endswith('.xml')]}


all_xmls.update(get_xml(folder))





p1=re.compile('\<detection\ (.*)\ \/\>')
p2=re.compile('[0-9]*\.?[0-9]*')
result_all=[]
counter=-1

#Batch converting the files

rackL = ""
repL = ""

for file in all_xmls[folder]:
    try:
        rackL.append(s1.findall(file)[0])
        repL.append(s2.findall(file)[0])
    except:
        pass
    
for file in os.listdir(folder):
    if file.startswith('Tracked_Batch_Preprocessed_VFlylapse') and file.endswith('.xml'):
        
        try:
            rackL=(s1.findall(file)[0])
            repL=(s2.findall(file)[0])
        except:
            pass
        
        with open(file) as f:
            
            
            result_young = []
            lines=f.readlines()
            for line in lines:
                if '<particle nSpots=' in line:
                    counter+=1
                if 'detection' in line:
                    _temp=filter(None, p2.findall(p1.findall(line)[0]))
                    result_all.append(['young',rackL,repL,'','','','','',str(counter)]+_temp)
                    result_young.append(['young',rackL,repL,'','','','','',str(counter)]+_temp)
                    csv_name = 'Young_Flies_Rack_'+rackL+'_Repet_'+str(repL)+'.csv'
                    
        with open(csv_name, 'w') as f:
            print>>f, 'Age,Rack,Repetition,Replicate,Predicted_bin,Nuclear,Mito,Diet,Track_ID,Time,x,y'
            for item in result_young:
                print>>f, ','.join(item[:-1])
            f.close()
        print csv_name
       
with open('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Young_Flies_All.csv', 'w') as f:
    print>>f, 'Age,Rack,Repetition,Replicate,Predicted_bin,Nuclear,Mito,Diet,Track_ID,Time,x,y'
    for item in result_all:
        print>>f, ','.join(item[:-1])
    f.close()
print 'Young_Flies_All.csv'

        
print "END"        


    
    
    
        
#        with open('Young_Flies_All.csv', 'w') as f:
#            print>>f, 'Age,Rack,Repetition,Replicate,Nuclear,Mito,Diet,Track_ID,Time,x,y'
#            for item in result:
#                print>>f, ','.join(item[:-1])
#        print 'Young_Flies_All.csv updated'
        
        


# Using Pandas in the Anaconda package to calculate the derivatives (displacement, velocity, and acceleration)
#df = pd.read_csv('Tracked_TracksOnly.csv')
# Out:
# Young_Flies_Rack_10_Repet_1.csv
# Young_Flies_Rack_10_Repet_2.csv
# Young_Flies_Rack_10_Repet_3.csv
# Young_Flies_Rack_11_Repet_1.csv
# Young_Flies_Rack_11_Repet_2.csv
# Young_Flies_Rack_11_Repet_3.csv
# Young_Flies_Rack_12_Repet_1.csv
# Young_Flies_Rack_12_Repet_2.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-642545afc2de> in <module>()
#      46         with open(file) as f:
#      47             result_young = []
# ---> 48             lines=f.readlines()
#      49             for line in lines:
#      50                 if '<particle nSpots=' in line:
#
# KeyboardInterrupt:

# %%
# OLD Flies XML to CSV - Script works
import os
folder = "/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/old_flies_xmls"
os.chdir(folder)

all_xmls = {}

def get_xml(folder):
    return {folder: [File for File in os.listdir(folder) if File.endswith('.xml')]}

all_xmls.update(get_xml(folder))

p1=re.compile('\<detection\ (.*)\ \/\>')
p2=re.compile('[0-9]*\.?[0-9]*')
result_all=[]

counter=-1

#Batch converting the files

rackL = ""
repL = ""


for file in all_xmls[folder]:
    try:
        rackL.append(s1.findall(file)[0])
        repL.append(s2.findall(file)[0])
    except:
        pass
    
for file in os.listdir(folder):
    if file.startswith('Tracked_Batch_Preprocessed_VFlylapse') and file.endswith('.xml'):
        
        try:
            rackL=(s1.findall(file)[0])
            repL=(s2.findall(file)[0])
        except:
            pass
        
        with open(file) as f:
            result_old = []
            lines=f.readlines()
            for line in lines:
                if '<particle nSpots=' in line:
                    counter+=1
                if 'detection' in line:
                    _temp=filter(None, p2.findall(p1.findall(line)[0]))
                    result_all.append(['old',rackL,repL,'','','','','',str(counter)]+_temp)
                    result_old.append(['old',rackL,repL,'','','','','',str(counter)]+_temp)
                    csv_name = 'Old_Flies_Rack_'+rackL+'_Repet_'+str(repL)+'.csv'
       
        with open(csv_name, 'w') as f:
            print>>f, 'Age,Rack,Repetition,Replicate,Predicted_bin,Nuclear,Mito,Diet,Track_ID,Time,x,y'
            for item in result_old:
                print>>f, ','.join(item[:-1])
            f.close()
        print csv_name
# Out:
# Old_Flies_Rack_10_Repet_1.csv
# Old_Flies_Rack_10_Repet_2.csv
# Old_Flies_Rack_10_Repet_3.csv
# Old_Flies_Rack_11_Repet_1.csv
# Old_Flies_Rack_11_Repet_2.csv
# Old_Flies_Rack_11_Repet_3.csv
# Old_Flies_Rack_12_Repet_1.csv
# Old_Flies_Rack_12_Repet_2.csv
# Old_Flies_Rack_12_Repet_3.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-0ffe1ac210a9> in <module>()
#      46                     counter+=1
#      47                 if 'detection' in line:
# ---> 48                     _temp=filter(None, p2.findall(p1.findall(line)[0]))
#      49                     result_all.append(['old',rackL,repL,'','','','','',str(counter)]+_temp)
#      50                     result_old.append(['old',rackL,repL,'','','','','',str(counter)]+_temp)
#
# KeyboardInterrupt:

# %%
#with open('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Old_Flies_All.csv', 'w') as f:
#    print>>f, 'Age,Rack,Repetition,Replicate,Predicted_bin,Nuclear,Mito,Diet,Track_ID,Time,x,y'
#    for item in result_all:
#        print>>f, ','.join(item[:-1])
#    f.close()
#print 'Old_Flies_All.csv'
#print 'END'
# Out:
# Old_Flies_Rack_10_Repet_1.csv
# Old_Flies_Rack_10_Repet_2.csv
# Old_Flies_Rack_10_Repet_3.csv
# Old_Flies_Rack_11_Repet_1.csv
# Old_Flies_Rack_11_Repet_2.csv
# Old_Flies_Rack_11_Repet_3.csv
# Old_Flies_Rack_12_Repet_1.csv
# Old_Flies_Rack_12_Repet_2.csv
# Old_Flies_Rack_12_Repet_3.csv
# Old_Flies_Rack_13_Repet_1.csv
# Old_Flies_Rack_13_Repet_2.csv
# Old_Flies_Rack_13_Repet_3.csv
# Old_Flies_Rack_14_Repet_1.csv
# Old_Flies_Rack_14_Repet_2.csv
# Old_Flies_Rack_14_Repet_3.csv
# Old_Flies_Rack_15_Repet_1.csv
# Old_Flies_Rack_15_Repet_2.csv
# Old_Flies_Rack_15_Repet_3.csv
# Old_Flies_Rack_16_Repet_1.csv
# Old_Flies_Rack_16_Repet_2.csv
# Old_Flies_Rack_16_Repet_3.csv
# Old_Flies_Rack_17_Repet_1.csv
# Old_Flies_Rack_17_Repet_2.csv
# Old_Flies_Rack_17_Repet_3.csv
# Old_Flies_Rack_18_Repet_1.csv
# Old_Flies_Rack_18_Repet_2.csv
# Old_Flies_Rack_18_Repet_3.csv
# Old_Flies_Rack_19_Repet_1.csv
# Old_Flies_Rack_19_Repet_2.csv
# Old_Flies_Rack_19_Repet_3.csv
# Old_Flies_Rack_1_Repet_3.csv
# ...

# %%
# Import data from csv
import pandas as pd

#df_old = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Old_Flies_All.csv')
#df_young = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Young_Flies_All.csv')
#df_young.groupby(['Track_ID','Age']).describe()
df_young.dropna().groupby(['Track_ID','Age','Rack','Repetition']).describe().to_excel('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Young_Flies_All_summary.xls')
df_old.groupby(['Track_ID','Age','Rack','Repetition']).describe().to_excel('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Old_Flies_All_summary.xls')
#df_old['old_summary']=df_old.groupby(['Track_ID','Age','Repetition']).describe()
#young_summary.to_excel('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Young_Flies_All_summary.csv')

#pd.concat([old_summary,young_summary]).to_excel('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Young_Flies_All_summary.csv')

# %%
import pandas as pd
#Old Flies.median(x)
#df = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Old_Flies_All.csv')
#x_median = df.groupby(['Age','Track_ID','Rack','Repetition']).x.median().to_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Old_Flies_All_medianx.csv')
#median_velocity=df.dropna.groupby(['Age','Track_ID','Rack','Repetition']).y.diff()/df.groupby(['Age','Track_ID','Rack','Repetition']).Time.diff().to_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Old_Flies_All_median_velocity.csv')

#Young Flies.median(x)
#df = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Young_Flies_All.csv')
#x_median = df.groupby(['Age','Track_ID','Rack','Repetition']).x.median().to_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Young_Flies_All_medianx.csv')
#y_median = df.groupby(['Age','Track_ID','Rack','Repetition']).y.median().to_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Young_Flies_All_medianx.csv')


#All Flies.median(x)
df = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/All_Flies_All.csv')
x_median = df.groupby(['Age','Track_ID','Rack','Repetition']).x.median().to_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/All_Flies_All_medianx.csv')
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-230-7d0371e508ff> in <module>()
#      13 #All Flies.median(x)
#      14 df = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/All_Flies_All.csv')
# ---> 15 x_median = df.groupby(['Age','Track_ID','Rack','Repetition']).x.median().to_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/All_Flies_All_medianx.csv')
#
# //anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in median(self)
#     677         """
#     678         try:
# --> 679             return self._cython_agg_general('median')
#     680         except GroupByError:
#     681             raise
#
# //anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _cython_agg_general(self, how, numeric_only)
#    1002
#    1003         if len(output) == 0:
# ...

# %%
#df_old = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Old_Flies_All.csv')
df = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Young_Flies_All.csv')


df['Dy'] = df.groupby(['Track_ID']).y.diff().dropna() # Relative distance


#df['Vy'] = df['Dy']/df.groupby(['Track_ID']).Time.diff() # Relative velocity
df['Velocity']
Velocity = df['Dy']/df.groupby(['Track_ID']).Time.diff().dropna() # Relative velocity
#Velocity2 =df.groupby('Track_ID').Velocity.agg(np.ptp)
#Velocity2

velocity2=df.groupby('Track_ID').Velocity.mean()

#df['Vy'] = df['Dy'].groupby(['Rack','Repetition','Track_ID'])/df.groupby(['Rack','Repetition','Track_ID']).Time.diff()
#df_old2 = df.dropna(subset=['Velocity'])
#df_old2 = df_old2[df_old2.Velocity>0]

#df_young2 = df_young.dropna(subset=['Velocity'])
#df_young2 = df_young2[df_young2.Velocity>0]
#df_young2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-241-d4d292810533> in <module>()
#      12 #Velocity2
#      13
# ---> 14 velocity2=df.groupby('Track_ID').Velocity.mean()
#      15
#      16 #df['Vy'] = df['Dy'].groupby(['Rack','Repetition','Track_ID'])/df.groupby(['Rack','Repetition','Track_ID']).Time.diff()
#
# //anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     484
#     485         raise AttributeError("%r object has no attribute %r" %
# --> 486                              (type(self).__name__, attr))
#     487
#     488     def __getitem__(self, key):
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'Velocity'

# %%
df = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Young_Flies_All.csv')

df2 = df.dropna(subset=['Dy'])
df2 = df2[df2.Dy>0]

df2 = df.dropna(subset=['Dy_abs'])
df2 = df2[df2.Dy_abs>0]

df2 = df.dropna(subset=['Dz'])
df2 = df2[df2.Dz>0]
#print df2.groupby('ID').Displacement.sum()


# Getting average velocities for Vy and Vz
df2 = df.dropna(subset=['Vy'])
ID_Vy_mean = df2.groupby('ID').Vy.mean() # Median of relative velocity
ID_Vy_median = df2.groupby('ID').Vy.median() # Median of relative velocity

df2 = df.dropna(subset=['Vy_abs'])
ID_Vy_abs_mean = df2.groupby('ID').Vy_abs.mean() # Median of relative velocity
ID_Vy_abs_median = df2.groupby('ID').Vy_abs.median() # Median of relative velocity

df2 = df.dropna(subset=['Vz'])
ID_Vz_mean = df2.groupby('ID').Vz.mean() # Mean of absolute velocity
ID_Vz_median = df2.groupby('ID').Vz.median() # Median of absolute velocity


# Getting average accelerations for Ay and Az
df2 = df.dropna(subset=['Ay'])
ID_Ay_mean = df2.groupby('ID').Ay.mean() # Median of relative acceleration
ID_Ay_median = df2.groupby('ID').Ay.median() # Median of relative acceleration

df2 = df.dropna(subset=['Ay_abs'])
ID_Ay_abs_mean = df2.groupby('ID').Ay_abs.mean() # Median of relative acceleration
ID_Ay_abs_median = df2.groupby('ID').Ay_abs.median() # Median of relative acceleration

df2 = df.dropna(subset=['Az'])
ID_Az_mean = df2.groupby('ID').Az.mean() # Mean of absolute acceleration
ID_Az_median = df2.groupby('ID').Az.median() # Median of absolute acceleration
print len(ID_Az_mean)
#df2.to_csv('Tracked_Tracks_Analysis2.csv')

df2 # Shows the complete data set for relative and absolute, velocities and accelerations
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-242-9976be3dabfe> in <module>()
#       2
#       3 df2 = df.dropna(subset=['Dy'])
# ----> 4 df2 = df2[df2.Dy>0]
#       5
#       6 df2 = df.dropna(subset=['Dy_abs'])
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Dy'

# %%
x_min = df.x.min()

x_max = df.x.max()

bin_6 = (x_max-x_min)/5



bin_24 = (x_max-x_min)/23



#6_bins = ((x_median-x_min)/x_max)*6
#6_bins

#x_norm = x_median-


#x_norm
# Out:
# 5.1363999070881574

# %%
import pandas as pd

#df = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/old_flies_csv/Old_Flies_Rack_9_Repet_1.csv')
#x_min = df.groupby(['Track_ID','Rack','Repetition']).x.min()
#x_max = df.groupby(['Track_ID','Rack','Repetition']).x.max()

#x_median = df.groupby(['Track_ID','Rack','Repetition']).x.median()
#x_range = (df.groupby(['Track_ID','Rack','Repetition']).x.max())-df.groupby(['Track_ID','Rack','Repetition']).x.min()
#x_cum = pd.DataFrame({'x_median': [x_median,'x_min': [x_min],'x_max': [x_max})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-24c9b87d3c82> in <module>()
#      11                      'x_max': [x_max[1:10]]})
#      12
# ---> 13 x_cum.ix['x_median']
#
# //anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      68             return self._getitem_tuple(key)
#      69         else:
# ---> 70             return self._getitem_axis(key, axis=0)
#      71
#      72     def _get_label(self, label, axis=0):
#
# //anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis, validate_iterable)
#     863                     return self._get_loc(key, axis=axis)
#     864
# --> 865             return self._get_label(key, axis=axis)
#     866
#     867     def _getitem_iterable(self, key, axis=0):
#
# ...

# %%
# Assigning lanes

#df_old = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Old_Flies_All.csv')
df_old['old_summary']=df_old.groupby(['Track_ID','Age']).describe()

old_summary.to_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Old_Flies_All_summary.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-8666be1914ea> in <module>()
#       2
#       3 #df_old = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Old_Flies_All.csv')
# ----> 4 df['old_summary']=df_old.groupby(['Track_ID','Age']).describe()
#       5
#       6 old_summary.to_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Old_Flies_All_summary.csv')
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv('/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/Master_csv/Young_Flies_All.csv')
# Calculating the values for the data frame containing derivative data
# NEED TO ADJUST FOR FRAME RATE = 15 Hz 



df['x_mean'] = df.groupby(['Track_ID']).x.mean() # Relative distance
bins = np.linspace(df.x.min(), df.x.max(), 24)
#groups = df.groupby(np.digitize(df.x_mean, bins))

bins

#df['Vy'] = df['Dy'].groupby(['Rack','Repetition','Track_ID'])/df.groupby(['Rack','Repetition','Track_ID']).Time.diff() # Relative velocity
#df.Vy.groupby(['Rack','Repetition','Track_ID'])





#df['Ay'] = df.groupby('ID').Vy.diff()/df.groupby('ID').Time.diff() # Relative acceleration
#!! Find a way to integrate

#df['Dy_abs'] = df.groupby('ID').y.diff().abs() # Relative distance
#df['Vy_abs'] = df['Dy_abs']/df.groupby('ID').Time.diff() # Relative velocity
#df['Ay_abs'] = df.groupby('ID').Vy_abs.diff()/df.groupby('ID').Time.diff() # Relative acceleration

#df['Dz'] = df.groupby('ID').x.diff().pow(2)+df.groupby('ID').y.diff().pow(2).pow(0.5) # NEED TO INTEGRATE!?!? Absolute distance. Displacement as the 'z' vector, solved for via pythag. This term will be compared to the 'y' vector, to give a measure of the linearity of the path. This should never be equal to 1, but should be as close to as possible.
#df['Vz'] = df['Dz']/df.groupby('ID').Time.diff() # Absolute velocity
#df['Az'] = df.groupby('ID').Vz.diff()/df.groupby('ID').Time.diff() # Absolute acceleration
#!! Find a way to integrate





# Write out to a new file for safe keeping
#df.to_csv('Tracked_Tracks_Analysis.csv') # Outputs the derivatives to a new file for easy access
#df # Shows a complete data frame including the displacement, velocities, and acceleration
# Out:
# array([  0.        ,   3.13020006,   6.26040012,   9.39060017,
#         12.52080023,  15.65100029,  18.78120035,  21.9114004 ,
#         25.04160046,  28.17180052])

# %%
# Working with the velocity and acceleration values requires the omission of the NaN cells

print(df.groupby('Track_ID').y.agg(np.ptp))
# Out:
# Track_ID
# 0            0.876418
# 1            2.700013
# 2            6.419806
# 3            1.394450
# 4            7.524387
# 5            7.559049
# 6            4.233701
# 7            6.233829
# 8            9.535546
# 9            9.650645
# 10           8.168814
# 11           8.215783
# 12          11.198908
# 13          12.380067
# 14           7.577029
# ...
# 5934        2.202122
# 5935        1.618185
# 5936        1.489411
# 5937        0.776578
# 5938        1.065488
# 5939        1.149836
# 5940        1.057025
# 5941        0.750164
# 5942        1.037225
# 5943        0.751076
# 5944        0.922311
# 5945        0.949219
# 5946        1.129985
# 5947        0.864625
# 5948        0.869327
# Name: y, Length: 5949, dtype: float64

# %%
df2 = df.dropna(subset=['Dy'])
df2 = df2[df2.Dy>0]

df2 = df.dropna(subset=['Dy_abs'])
df2 = df2[df2.Dy_abs>0]

df2 = df.dropna(subset=['Dz'])
df2 = df2[df2.Dz>0]
#print df2.groupby('ID').Displacement.sum()


# Getting average velocities for Vy and Vz
df2 = df.dropna(subset=['Vy'])
ID_Vy_mean = df2.groupby('ID').Vy.mean() # Median of relative velocity
ID_Vy_median = df2.groupby('ID').Vy.median() # Median of relative velocity

df2 = df.dropna(subset=['Vy_abs'])
ID_Vy_abs_mean = df2.groupby('ID').Vy_abs.mean() # Median of relative velocity
ID_Vy_abs_median = df2.groupby('ID').Vy_abs.median() # Median of relative velocity

df2 = df.dropna(subset=['Vz'])
ID_Vz_mean = df2.groupby('ID').Vz.mean() # Mean of absolute velocity
ID_Vz_median = df2.groupby('ID').Vz.median() # Median of absolute velocity


# Getting average accelerations for Ay and Az
df2 = df.dropna(subset=['Ay'])
ID_Ay_mean = df2.groupby('ID').Ay.mean() # Median of relative acceleration
ID_Ay_median = df2.groupby('ID').Ay.median() # Median of relative acceleration

df2 = df.dropna(subset=['Ay_abs'])
ID_Ay_abs_mean = df2.groupby('ID').Ay_abs.mean() # Median of relative acceleration
ID_Ay_abs_median = df2.groupby('ID').Ay_abs.median() # Median of relative acceleration

df2 = df.dropna(subset=['Az'])
ID_Az_mean = df2.groupby('ID').Az.mean() # Mean of absolute acceleration
ID_Az_median = df2.groupby('ID').Az.median() # Median of absolute acceleration
print len(ID_Az_mean)
df2.to_csv('Tracked_Tracks_Analysis2.csv')

df2 # Shows the complete data set for relative and absolute, velocities and accelerations
# Out:
# 43
#      ID  Time          x          y        Dy        Vy        Ay    Dy_abs  \
# 2     0     2  20.193634  16.058533  0.838277  0.838277  0.906379  0.838277
# 3     0     3  20.179487  14.811962 -1.246571 -1.246571 -2.084848  1.246571
# 4     0     4  20.235525  15.164238  0.352276  0.352276  1.598847  0.352276
# 5     0     5  20.154211  15.268805  0.104567  0.104567 -0.247709  0.104567
# 6     0     6  20.246058  14.222756 -1.046048 -1.046048 -1.150615  1.046048
# 7     0     7  20.249450  14.209880 -0.012876 -0.012876  1.033172  0.012876
# 8     0     8  20.137112  12.998501 -1.211380 -1.211380 -1.198504  1.211380
# 9     0     9  20.235807  11.168718 -1.829783 -1.829783 -0.618403  1.829783
# 10    0    10  20.250549  11.241740  0.073023  0.073023  1.902806  0.073023
# 11    0    11  20.249345  11.141654 -0.100086 -0.100086 -0.173109  0.100086
# 12    0    12  20.244194  11.134331 -0.007323 -0.007323  0.092762  0.007323
# ...

# %%
# Binning the flies by x-coordinate


x_mean = df2.groupby('ID').x.median()

x_mean_sort = x_mean.sort()
x_mean_sort


x_mean.plot(df2.groupby('ID').y)



#x_mean.hist(label = str(df2.groupby('ID')), bins = 6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-5705999d6f59> in <module>()
#       8
#       9
# ---> 10 x_mean.plot(df2.groupby('ID').y, kind='.')
#      11
#      12
#
# //anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    2220         klass = _plot_klass[kind]
#    2221     else:
# -> 2222         raise ValueError('Invalid chart type given %s' % kind)
#    2223
#    2224     """
#
# ValueError: Invalid chart type given .

# %%
ID_Vz_mean.hist(label="Vz")

#ID_Vy_mean.hist(label="Vy")

ID_Vy_abs_mean.hist(label="Vy_abs")
    plt.title("Mean Velocity")
    plt.xlabel("Velocity (cm/s)")
    plt.ylabel("Frequency")
    plt.legend()

# %% [markdown]
# ### # Make histogram of velocity and acceleration

# %%
plt.hist(ID_V_mean)
plt.figure()
plt.hist(ID_A_mean)
# Out:
# (array([  1.,   3.,   0.,   6.,  11.,   6.,   7.,   5.,   1.,   3.]),
#  array([-0.15955429, -0.13404832, -0.10854236, -0.0830364 , -0.05753043,
#         -0.03202447, -0.0065185 ,  0.01898746,  0.04449343,  0.06999939,
#          0.09550536]),
#  <a list of 10 Patch objects>)

# %%
for i in range(1,10):
    plt.plot(df.Time[df.ID==i],df.Vz[df.ID==i], label="Track %s" % i)
    plt.title("Tracks 1-%s" % i)
    plt.xlabel("Time(sec)")
    plt.ylabel("Velocity (cm/s)")
    plt.legend()
# Out:
# Traceback (most recent call last):
#
#   File "//anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.py", line 389, in execute_request
#     shell.run_cell(code, store_history=store_history, silent=silent)
#
#   File "//anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2743, in run_cell
#     self.events.trigger('post_execute')
#
#   File "//anaconda/lib/python2.7/site-packages/IPython/core/events.py", line 82, in trigger
#     func(*args, **kwargs)
#
#   File "//anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/pylab/backend_inline.py", line 118, in flush_figures
#     return show(True)
#
#   File "//anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/pylab/backend_inline.py", line 47, in show
#     matplotlib.pyplot.close('all')
#
#   File "//anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py", line 511, in close
#     _pylab_helpers.Gcf.destroy_all()
#
# ...

# %%
# Not ready

# %%R

doc <- read.csv("/Users/aspierer/Desktop/Fly Tracking/Tracked_Tracks_Analysis2.csv", colClasses=c('factor', rep('numeric',3)))
summary(doc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-0b5cbd87e260> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'R', u'', u'\ndoc <- read.csv("/Users/aspierer/Desktop/Fly Tracking/Tracked_Tracks_Analysis2.csv", colClasses=c(\'factor\', rep(\'numeric\',3)))\nsummary(doc)           ')
#
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2160             magic_arg_s = self.var_expand(line, stack_depth)
#    2161             with self.builtin_trap:
# -> 2162                 result = fn(magic_arg_s, cell)
#    2163             return result
#    2164
#
# //anaconda/lib/python2.7/site-packages/IPython/extensions/rmagic.pyc in R(self, line, cell, local_ns)
#
# //anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
# ...

# %%
# Verbose was of getting a list of the xml names
    # Change this to a function in later versions: look into glob for tree/directory searching
    

#folder = "/Users/aspierer/Desktop/Fly Tracking/young_flies_xmls/"

all_xmls = {}

def get_xml(folder):
    return {folder: [File for File in os.listdir(folder) if File.endswith('.xml')]}

folder = "/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/young_flies_xmls"
all_xmls.update(get_xml(folder))

folder = "/Users/aspierer/Desktop/Fly Tracking/HHMI_tracked_files/old_flies_xmls"
all_xmls.update(get_xml(folder))

#all_xmls
#S = "Tracked_Batch_Preprocessed_VFlylapse_Rack10_Rep2_19-54-03.tif.xml"
old_flies_xmls = []
rackL = []
repL = []


s1=re.compile('Rack([0-9]*)_')
s2=re.compile('Rep([0-9]*)_')

p1=re.compile('\<detection\ (.*)\ \/\>')
p2=re.compile('[0-9]*\.?[0-9]*')
result=[]
counter=-1
for file in all_xmls[folder]:
    try:
        rackL.append(s1.findall(file)[0])
        repL.append(s2.findall(file)[0])
    except:
        pass
#(rackL, repL)

for file in os.listdir(folder):
	if file.startswith('Tracked_Batch_Preprocessed_VFlylapse') and file.endswith('.xml'):
		old_flies_xmls.append(file)
